# %% [markdown]
# 2017 연도별 데이터, 데이터 프레임 하나로 합치고 싶어 => 하나로 합쳐보기

# %%
import pandas as pd
import os

# %%
#원래는 이렇게 불러왔음
#pd.read_csv("../csv/2017/201701_expense_list.csv")

#지정된 경로에 있는 파일 목록을 불러오기
files = os.listdir("../csv/2017") #파일명을 지정
files
#리스트 형태로 파일목록이 불러와진 것을 확인할 수 있음
# Out:
# ['201701_expense_list.csv',
#  '201702_expense_list.csv',
#  '201703_expense_list.csv',
#  '201704_expense_list.csv',
#  '201705_expense_list.csv',
#  '201706_expense_list.csv',
#  '201707_expense_list.csv',
#  '201708_expense_list.csv',
#  '201709_expense_list.csv',
#  '201710_expense_list.csv',
#  '201711_expense_list.csv',
#  '201712_expense_list.csv']

# %% [markdown]
# 1. 파일 목록 출력
# 2. 파일 목록을 불러와서 concat() 함수 이용해 하나의 데이터프레임으로 결합

# %%
df_2017 = pd.DataFrame()

path = "../csv/2017/"

for file in files:
    df = pd.read_csv(path+file)
    df_2017 = pd.concat([df_2017, df], axis=0, ignore_index=True) #안적어도 되긴함

# %%
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70132 entries, 0 to 70131
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nid                70132 non-null  int64
#  1   title              70132 non-null  object
#  2   url                70132 non-null  object
#  3   dept_nm_lvl_1      70132 non-null  object
#  4   dept_nm_lvl_2      70074 non-null  object
#  5   dept_nm_lvl_3      61262 non-null  object
#  6   dept_nm_lvl_4      17939 non-null  object
#  7   dept_nm_lvl_5      3474 non-null   object
#  8   exec_yr            70132 non-null  int64
#  9   exec_month         70132 non-null  int64
#  10  expense_budget     3108 non-null   float64
#  11  expense_execution  2805 non-null   float64
#  12  category           1259 non-null   object
#  13  dept_nm_full       70053 non-null  object
#  14  exec_dt            70132 non-null  object
#  15  exec_loc           69360 non-null  object
# ...

# %%
files18 = os.listdir("../csv/2018")

df_2018 = pd.DataFrame()

path18 = "../csv/2018/"

for file in files18:
    df18 = pd.read_csv(path18 + file)
    df_2018 = pd.concat([df_2018, df18])

df_2018.head()
# Out:
#         nid                                 title  \
# 0  14618781  2018년 1월 서울시본청 기후환경본부 환경정책과 업무추진비 내역
# 1  14618781  2018년 1월 서울시본청 기후환경본부 환경정책과 업무추진비 내역
# 2  14618781  2018년 1월 서울시본청 기후환경본부 환경정책과 업무추진비 내역
# 3  14618781  2018년 1월 서울시본청 기후환경본부 환경정책과 업무추진비 내역
# 4  14618781  2018년 1월 서울시본청 기후환경본부 환경정책과 업무추진비 내역
#
#                                           url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0  http://opengov.seoul.go.kr/public/14618781         서울시본청        기후환경본부
# 1  http://opengov.seoul.go.kr/public/14618781         서울시본청        기후환경본부
# 2  http://opengov.seoul.go.kr/public/14618781         서울시본청        기후환경본부
# 3  http://opengov.seoul.go.kr/public/14618781         서울시본청        기후환경본부
# 4  http://opengov.seoul.go.kr/public/14618781         서울시본청        기후환경본부
#
#   dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr  exec_month  \
# 0         환경정책과           NaN           NaN     2018           1
# 1         환경정책과           NaN           NaN     2018           1
# ...

# %%
df_2017.head(1)
# Out:
#         nid                         title  \
# 0  11430252  2017년 1월 장애인복지정책과 업무추진비 집행내역
#
#                                           url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0  http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
#
#   dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr  exec_month  \
# 0      장애인복지정책과           NaN           NaN     2017           1
#
#    expense_budget  expense_execution category   dept_nm_full  \
# 0             NaN                NaN      NaN  복지본부 장애인복지정책과
#
#             exec_dt       exec_loc       exec_purpose       target_nm  \
# 0  2017-01-26 13:10  동해일식 (중구 무교동)  기본소득과 장애인복지 논의간담회  장애인복지정책팀장 외 2명
#
#   payment_method  exec_amount
# 0             카드        76000

# %%
df_2018.head(1)
# Out:
#         nid                                 title  \
# 0  14618781  2018년 1월 서울시본청 기후환경본부 환경정책과 업무추진비 내역
#
#                                           url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0  http://opengov.seoul.go.kr/public/14618781         서울시본청        기후환경본부
#
#   dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr  exec_month  \
# 0         환경정책과           NaN           NaN     2018           1
#
#    expense_budget  expense_execution category  dept_nm_full           exec_dt  \
# 0             NaN                NaN      NaN  기후환경본부 환경정책과  2018-01-31 20:08
#
#    exec_loc                                     exec_purpose      target_nm  \
# 0  남도한식　고운님  환수위 2018년 본부 현안사업 추진 협력방안 검토 간담회 실시 비용 지출(1.31)  기후환경본부장 외 15명
#
#   payment_method  exec_amount
# 0             카드       283000

# %%
total_df = pd.concat([df_2017, df_2018])
total_df.tail(1)
# Out:
#            nid                                      title  \
# 7704  17400394  2018년 12월 서울시본청 행정국 총무과 업무추진비 - 기관운영 시책추진
#
#                                              url dept_nm_lvl_1 dept_nm_lvl_2  \
# 7704  http://opengov.seoul.go.kr/public/17400394         서울시본청           행정국
#
#      dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr  exec_month  \
# 7704           총무과           NaN           NaN     2018          12
#
#       expense_budget  expense_execution     category dept_nm_full  \
# 7704             NaN                NaN  시정 관련 간담회 등      행정국 총무과
#
#                exec_dt exec_loc    exec_purpose target_nm payment_method  \
# 7704  2018-12-01 08:45   종가집설렁탕  시정 정책 지역협력 간담회   시장 외 9명             카드
#
#       exec_amount
# 7704       180000

# %%
len(total_df)
# Out:
# 142350

# %% [markdown]
# # json 파일 / xlsx 엑셀 파일 로드

# %%
# jsno 형태는 dict 형태
# 이거는 csv와 동일
pd.read_json("../csv/2019/201901_expense_list.json")

# xlsx면 이렇게 해도 가능한데, xlsm이라 안됨
pd.read_excel("../csv/2020/202001_expense_list.xlsx")

# %%
# !pip install openpyxl

# %%
pd.read_excel("../csv/2020/202001_expense_list.xlsx", engine="openpyxl")
# Out:
#            nid                                             title  \
# 0     21789676             2020년 1월 사업소 서울식물원 시설운영과 업무추진비 - 부서운영
# 1     21762080   2020년 1월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 부서운영
# 2     21762080   2020년 1월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 부서운영
# 3     21762080   2020년 1월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 부서운영
# 4     21762080   2020년 1월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 부서운영
# ...        ...                                               ...
# 5277  19740729  2020년 1월 서울시본청 시민소통기획관 시민소통담당관 업무추진비 - 기관운영 시책추진
# 5278  19740729  2020년 1월 서울시본청 시민소통기획관 시민소통담당관 업무추진비 - 기관운영 시책추진
# 5279  19740729  2020년 1월 서울시본청 시민소통기획관 시민소통담당관 업무추진비 - 기관운영 시책추진
# 5280  19740729  2020년 1월 서울시본청 시민소통기획관 시민소통담당관 업무추진비 - 기관운영 시책추진
# 5281  19740729  2020년 1월 서울시본청 시민소통기획관 시민소통담당관 업무추진비 - 기관운영 시책추진
#
#                                              url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0     http://opengov.seoul.go.kr/public/21789676           사업소         서울식물원
# ...

# %%
# dataframe 정보확인
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142350 entries, 0 to 7704
# Data columns (total 20 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   nid                142350 non-null  int64
#  1   title              142350 non-null  object
#  2   url                142350 non-null  object
#  3   dept_nm_lvl_1      142350 non-null  object
#  4   dept_nm_lvl_2      142156 non-null  object
#  5   dept_nm_lvl_3      124092 non-null  object
#  6   dept_nm_lvl_4      37693 non-null   object
#  7   dept_nm_lvl_5      6874 non-null    object
#  8   exec_yr            142350 non-null  int64
#  9   exec_month         142350 non-null  int64
#  10  expense_budget     6001 non-null    float64
#  11  expense_execution  5015 non-null    float64
#  12  category           2985 non-null    object
#  13  dept_nm_full       142271 non-null  object
#  14  exec_dt            142350 non-null  object
# ...

# %% [markdown]
# # total_df
# 1. 컬럼의 이름 변경 ['nid', '제목', 'url', '부서레벨1', '부서레벨2', '부서레벨3', '부서레벨4', '부서레벨5', '집행연도', '집행일', '예산', '집행', '구분', '부서명', '집행일시', '집행장소', '집행목적', '대상인원', '결제방법', '집행금액']
# 2. 컬럼 삭제 -> 부서레벨3, 부서레벨4, 부서레벨5, 예산, 집행, 구분
# 3. 연도별 집행금액의 합 구하고 -> 시각화 (바형 그래프)
# 4. 연도, 월 별 집행금액 합계를 시각화 (바형 그래프)

# %%
total_df = pd.concat([df_2017, df_2018])
total_df.tail(1)

# %%
total_df.columns = ['nid', '제목', 'url', '부서레벨1', '부서레벨2', '부서레벨3', '부서레벨4', '부서레벨5', '집행연도', '집행일', '예산', '집행', '구분', '부서명', '집행일시', '집행장소', '집행목적', '대상인원', '결제방법', '집행금액']
total_df.head(1)
# Out:
#         nid                            제목  \
# 0  11430252  2017년 1월 장애인복지정책과 업무추진비 집행내역
#
#                                           url  부서레벨1 부서레벨2     부서레벨3 부서레벨4  \
# 0  http://opengov.seoul.go.kr/public/11430252  서울시본청  복지본부  장애인복지정책과   NaN
#
#   부서레벨5  집행연도  집행일  예산  집행   구분            부서명              집행일시  \
# 0   NaN  2017    1 NaN NaN  NaN  복지본부 장애인복지정책과  2017-01-26 13:10
#
#             집행장소               집행목적            대상인원 결제방법   집행금액
# 0  동해일식 (중구 무교동)  기본소득과 장애인복지 논의간담회  장애인복지정책팀장 외 2명   카드  76000

# %%
total_df.drop(['부서레벨3', '부서레벨4', '부서레벨5', '예산', '집행', '구분'], axis='columns', inplace=True)

# %%
total_df.head(1)
# Out:
#         nid                            제목  \
# 0  11430252  2017년 1월 장애인복지정책과 업무추진비 집행내역
#
#                                           url  부서레벨1 부서레벨2  집행연도  집행일  \
# 0  http://opengov.seoul.go.kr/public/11430252  서울시본청  복지본부  2017    1
#
#              부서명              집행일시           집행장소               집행목적  \
# 0  복지본부 장애인복지정책과  2017-01-26 13:10  동해일식 (중구 무교동)  기본소득과 장애인복지 논의간담회
#
#              대상인원 결제방법   집행금액
# 0  장애인복지정책팀장 외 2명   카드  76000

# %%
# 집행 연도를 기준으로 그룹화해서 집행금액의 합계를 출력
month_total = total_df.groupby('집행연도').sum()['집행금액']
month_total
# Out:
# 집행연도
# 2017    9076941387
# 2018    9937556542
# Name: 집행금액, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
# 이게 내 생각인데 교수님 풀이도 동일하네

# 바형 그래프
# x축 -> index
# y축 -> 집행금액의 합계

x = month_total.index
y = month_total

plt.bar(x, y)
plt.show()

# %%
# 2 위 방법말고 다른 방법을 써보자!
# 피벗테이블

# pivot_table()의 형태로 변경 시각화
# groupby랑 같이 피벗테이블 형태로 묶는 것
month_total = pd.pivot_table(total_df, index=['집행연도'], values=['집행금액'], aggfunc='sum')
month_total
# Out:
#             집행금액
# 집행연도
# 2017  9076941387
# 2018  9937556542

# %%
# 한글이 깨져서 한글 세팅
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

(month_total).plot.bar()

# 피벗테이블 형태만 잘 그리면 그리기 훨씬 쉬움
# x축과 범례 자동으로 잡힘
# Out:
# <AxesSubplot:xlabel='집행연도'>

# %%
(month_total).plot.barh()
# 이렇게 h만 붙이면 바가 회전
# Out:
# <AxesSubplot:ylabel='집행연도'>

# %%
# 연도별 월별
month_total = total_df.groupby(['집행연도', '집행일']).sum()['집행금액']
month_total
# Out:
# 집행연도  집행일
# 2017  1       710368860
#       2       712679864
#       3       737250454
#       4       635265805
#       5       647582378
#       6       758257342
#       7       701604626
#       8       661174850
#       9       806170700
#       10      637219943
#       11      843619171
#       12     1225747394
# 2018  1       735587570
#       2       769360005
#       3       761059010
#       4       703781418
#       5       669044701
#       6       690652154
#       7       788926477
#       8       730290532
#       9       769404957
#       10      827022975
#       11      960310221
#       12     1532116522
# Name: 집행금액, dtype: int64

# %%
month_total.plot.bar()
# Out:
# <AxesSubplot:xlabel='집행연도,집행일'>

# %%
pivot_month = pd.pivot_table(total_df, index=['집행일'], columns=['집행연도'], values=['집행금액'], aggfunc='sum')
pivot_month                             #인덱스가 두 개면 이렇게 columns까지
# Out:
#             집행금액
# 집행연도        2017        2018
# 집행일
# 1      710368860   735587570
# 2      712679864   769360005
# 3      737250454   761059010
# 4      635265805   703781418
# 5      647582378   669044701
# 6      758257342   690652154
# 7      701604626   788926477
# 8      661174850   730290532
# 9      806170700   769404957
# 10     637219943   827022975
# 11     843619171   960310221
# 12    1225747394  1532116522

# %%
(pivot_month).plot.bar()
# Out:
# <AxesSubplot:xlabel='집행일'>

# %% [markdown]
# 집행연도와 부서레벨1 별 집행금액의 평균이 어떠한가 그래프로 표시

# %%
lv1_mean = pd.pivot_table(total_df, index=['부서레벨1'], columns=['집행연도'], values=['집행금액'], aggfunc='mean')
lv1_mean
# Out:
#                       집행금액
# 집행연도                  2017           2018
# 부서레벨1
# 사업소          120432.199322  124290.371469
# 서울시본청        119812.339642  130286.126921
# 소방재난본부(소방서)  215503.983578  226244.982045
# 의회사무처        101912.491923  104341.926548

# %%
lv1_mean.plot.bar()
# Out:
# <AxesSubplot:xlabel='부서레벨1'>
